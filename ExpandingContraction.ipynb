# %%
import numpy as np
import pandas as pd
from IPython.display import display
pd.set_option('display.max_colwidth',-1) # set max col width in order we can some more content
# Out:
# <ipython-input-1-13ab9fd3e640>:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth',-1) # set max col width in order we can some more content

# %%
abbr_dict={
    "abg":"abang" ,
    "ade":"ada",
    "ader":"ada",
    "ado":"ada",
    "hado":"ada",
    "adk":"adik" ,
    "adek":"adik" ,
    "adeq":"adik" ,  
    "adlh":"adalah",     
    "agk":"agak" ,
    "aje":"sahaja" ,
    "ajer":"sahaja" ,
    "je":"sahaja" ,
    "shj":"sahaja" ,
    "ja":"sahaja" ,
    "jek":"sahaja" ,
    "jer":"sahaja" ,
    "jerk":"sahaja" ,
    "saje":"sahaja" ,
    "ak":"aku",
    "ako":"aku",
    "biaq":"bia",
    "aq":"aku",
    "akk":"kakak",
    "akn":"akan",
   "ambik":"ambil"  ,
   "amek":"ambil"  ,
   "hambek":"ambil"  ,
   "ank":"anak" ,
   "ap":"apa" ,
   "aper":"apa" ,
   "hapa":"apa" ,
   "haper":"apa" ,
   "apasal":"kenapa",
   "apesal":"kenapa",
   "apahal":"kenapa",
   "apehal":"kenapa",
   "apetah":"apa entah",
   "arap":"harap",
   "ari":"hari",
   "aritu":"haritu" ,
   "asl":"asal" ,
   "ati":"hati",
    "ats":"atas",
    "awat":"kenapa" ,
    "awt":"kenapa" ,
    "awk":"awak" ,
    "awl":"awal" ,
    "ayer":"air" ,
    "ayh":"ayah" ,
    "ayt":"ayat",
    "bagitau":"beritahu",
    "bgitau":"beritahu",
    "bgtu":"beritahu",
    "bgtaw":"beritahu",
    "bitau":"beritahu",
    "bape":"berapa",
    "baper":"berapa",
    "brp":"berapa",
    "bpe":"berapa",
    "braper":"berapa",
    "brp":"berapa",
    "BC":"baca" ,
    "BCA":"baca" ,
    "bdn":"badan",
    "bdoh":"bodoh" ,
    "beger":"burger"  ,
    "bekfes":"sarapan" ,
    "belen":"baki",
    "beno":"benar",
    "benor":"benar",
    "bnr":"benar",
    "bbeno":"benar-benar",
    "bebeno":"benar-benar",
    "bebenor":"benar-benar",
     "bes":"seronok" ,
    "besaq":"besar" ,
    "beso":"besar" ,
    "besor":"besar" ,
    "bese":"biasa" ,
    "biase":"biasa" ,
    "betoi":"betul" ,
    "betol":"betul" ,
    "betui":"betul" ,
     "bg":"bahagi",
    "bgi":"bahagi",
    "bgai":"bagai" ,
    "bgn":"bangun" ,
    "bgs":"bagus",
    "bgus":"bagus", 
   "bgsa":"bangsa",
   "bgun":"bangun",
   "bhasa":"bahasa" ,
   "bhs":"bahasa" ,
   "bhse":"bahasa",
   "bhgn":"bahagian",
   "bhn":"bahan" ,
   "biaq":"biar",
   "bile":"bila",
   "blah":"bila",
   "ble":"bila",
   "bior":"biar",
   "bj":"baju",
    "bju":"baju",
    "bjet":"bajet",
    "bjya":"berjaya",
    "bk":"buka",
    "bka":"buka",
    "bkak":"buka",
    "bkk":"buka",
    "bkn":"bukan",
    "blah":"belah",
    "blaja":"belajar",
    "blja":"belajar",
    "bljar":"belajar",
    "bljr":"belajar",
    "bleh":"boleh",
    "blh":"boleh",
    "bley":"boleh",
      "blek":"balik",
      "blik":"balik",
      "blk":"balik",
      "blkg":"belakang",
      "blkng":"belakang",
      "blj":"belanja",
      "blnja":"belanja",
      "bls":"balas",
      "bnd":"benda" ,
      "bnde":"benda" ,
      "bntu":"bantu",
      "borg":"borang",
      "borng":"borang",
      "br":"baru",
      "brader":"abang" ,
      "brg":"barang" ,
      "brlku":"berlaku",
      "bru":"baru",
      "BSR":"besar",
      "bsar":"besar",
      "wat":"buat",
      "bt":"buat",
      "wt":"buat",
      "btl":"betul",
      "btpe":"buat apa",
      "watpe":"buat apa",
      "wtpe":"buat apa" ,
      "bw":"bawa",
      "bwa":"bawa",
      "bwak":"bawa",
      "bwh":"bawah",
      "byk":"banyak",
      "bnyk":"banyak",
      "byr":"bayar",
      "ni":"ini",
      "camna":"macam mana",
      "camne":"macam mana",
      "camner":"macam mana",
      "cmna":"macam mana",
      "cmne":"macam mana",
      "cmner":"macam mana",
      "cmana":"macam mana",
      "cmane":"macam mana",
      "cmaner":"macam mana",
      "camni":"macam ini",
      "cmnie":"macam ini",
      "cer":"cuba",
      "cdgn":"cadangan",
      "cdgan":"cadangan",
      "cdgkn":"cadangkan",
      "cdgkan":"cadangkan",
      "cite":"cerita",
      "citer":"cerita",
      "crita":"cerita" ,
      "crite":"cerita",
      "cter":"cerita",
       "skit":"sedikit",
       "ckap":"cakap" ,
      "br":"baru",
      "mcm":"macam",
      "cmburu":"cemburu",
      "cmpur":"campur",
      "cmtu":"macam itu",
      "cnta":"cinta",
      "cntik":"cantik",
      "cntk":"cantik",
      "comei":"comel",
      "cpt":"cepat",
      "dh":"sudah",
       "dduk":"duduk",
       "dek":"adik",
       "dorg":"mereka",
       "diaorg":"mereka",
       "diaorg":"mereka",
       "dorng":"mereka",
        "dgr":"dengar",
        "dgar":"dengar",
        "dkt":"dekat",
        "dlu":"dulu",
        "dpn":"depan",
        "drpd":"daripada",
        "dtg":"datang",
        "fhm":"faham",
        "fkir":"fikir" ,
         "gado":"gaduh",
         "giler":"gila",
         "hbgn":"hubungan",
         "hdp":"hadap",
         "hg":"awak",
         "hjg":"hujung",
         "hmpa":"hampa",
         "hmpir":"hampir",
         "hntr":"hantar",
         "hrga":"harga",
         "hrp":"harap",
         "igt":"ingat",
         "jap":"sekejap",
         "jeles":"cemburu",
         "Jln":"jalan" ,
         "jnis":"jenis",
         "jnji":"janji",
         "jntn":"jantan",
         "jwtn":"jawatan",
         "Kabo":"khabar" ,
         "Kate":"kata",
         "kecik":"kecil",
         "kdg2":"kadang-kadang" ,
         "keje":"kerja",
         "kite":"kita",
         "klu":"kalau",
         "knl":"kenal",
         "knp":"kenapa",
         "korg":"korang" ,
           "ktorg":"kami" ,
           "kwn":"kawan" ,
           "kwsn":"kawasan",
           "lgi":"lagi",
          "lgpun":"lagipun",
           "lmbt":"lambat",
           "mende":"benda",
           "mggu":"minggu",
           "mkn":"makan",
           "mksd":"maksud",
           "mmg":"memang",
           "mslh":"masalah" ,
           "msti":"mesti" ,
           "dgn":"dengan",
        "nmpk":"nampak",
         "nnt":"nanti" ,
             "nye":"hanya",
           "pdhal":"padahal",
           "pebenda":"apabenda",
           "pgi":"pagi",
           "pjg":"panjang",
           "plk":"pula",
           "pndai":"pandai",
           "prnah":"pernah" ,
           "pnting":"penting",
           "pnye":"punya",
           "psl":"pasal" ,
           "pstu":"selepas itu",
           "ptg":"petang",
           "ptt":"patut",
           "pyh":"payah" ,
           "retis":"artis",
           "rkyt":"rakyat" ,
           "rsa":"rasa",
           "rse":"rasa",
           "sado":"sasa" ,
           "sape":"siapa" ,
           "sbr":"sabar" ,
           "scr":"secara",
           "sdar":"sedar",
           "sgala":"segala",
           "sggh":"singgah",
           "snggup":"sanggup",
           "sgguh":"sungguh",
           "sgka":"sangka" ,
           "sgt":"sangat",
           "shbt":"sahabat",
           "skrg":"sekarang",
           "suke":"suka",
           "slmt":"selamat",
           "smlm":"semalam",
           "sndiri":"sendiri",
           "sng":"senang",
           "sorg":"seorang",
           "sy":"saya" ,
           "bia":"biar",
           "syg":"sayang" ,
           "tido":"tidur",
           "tggjwb":"tanggungjawab" ,
           "tggl":"tinggal",
           "tgh":"tengah",
           "tgk":"tengok",
           "tgn":"tangan",
           "tkt":"takat",
           "tkut":"takut",
           "tlg":"tolong",
            "tpi":"tapi" ,
           "tpt":"tepat",
           "wlu":"walau",
           "wlpun":"walaupun",
           "wslm":"waalaikumusalam" ,
           "xde":"tak ada",
           "xder":"tak ada",
           "takde":"tak ada",
           "takder":"tak ada",
           "xkn":"takkan",
           "xkan":"takkan",
         
           "xleh":"tak boleh",
           "takleh":"tak boleh",
           "xmau":"takmahu",
           "xnk":"tak nak" ,
           "xnak":"tak nak", 
           "taknak":"tak nak" ,
            "xpe":"tak apa",
           "takpe":"tak apa",
           "takpe":"tak apa",
           "zmn":"zaman" 
}

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

#Importing csv file
df = pd.read_csv('/content/Book2.csv')

# %%
def process_data(file_name):
    data=pd.read_csv(file_name)
    data.Text=data.Text.str.lower() # conver to lower case
    data.Text=data.Text.astype(str)
    data.replace(abbr_dict,regex=True,inplace=True)
    return data

# %%
a = (
   df.Text.str.replace('[...…]','')
    .str.split()
    .apply(lambda x: ' '.join([abbr_dict.get(e, e) for e in x]))
)
# Out:
# <ipython-input-15-8ad86a6c2183>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.Text.str.replace('[...…]','')

# %%
a
# Out:
# 0    biar pi lah diorang
# 1    Aku selalu biar sahaja diorang main
# 2    Kau perlukan bahan seperti ini
# 3    Kau kena buat macam ini kenal
# Name: Text, dtype: object

# %%
a.to_csv('CleanedData2.csv')

# %%
train_df=process_data('/content/Book2.csv')

# %%
train_df
# Out:
#                                    Text
# 0  biar pi lah diorang
# 1  akuu selalu biar sahaja diorang main
# 2  kau perlukan bahan seperti ni
# 3  kau kena buat macam ni kenal
